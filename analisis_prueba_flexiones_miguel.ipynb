# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('docs/data/csv/flexiones_miguel.csv')

# %%
df.drop(columns=["canal1","canal2","canal3","canal4"], inplace=True)

# %%
df.head()
# Out:
#    intervalos  canal5
# 0           0     515
# 1           1     501
# 2           2     524
# 3           3     517
# 4           4     512

# %%
df.plot(
    y=["canal5"],
    title="Canal 5",
    figsize=(15,5)
)
# Out:
# <Axes: title={'center': 'Canal 5'}>

# %%
df.plot(
    y=["intervalos"],
    title="Intervalos",
    figsize=(15,5),
    colormap="viridis"
)
# Out:
# <Axes: title={'center': 'Intervalos'}>
